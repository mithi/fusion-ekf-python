# %%
from datapoint import DataPoint
import numpy as np

from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import HoverTool
from bokeh.models import ColumnDataSource
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e7299284-645f-4b15-9447-fdd02af9fa76">Loading BokehJS ...</span>
#     </div>

# %%
def parse_in_data(file_path):
  """
    Args:
    file_path 

          R 8.46642 0.0287602 -3.04035  1477010443399637  8.6 0.25  -3.00029  0
          (R) (rho) (phi) (drho) (timestamp) (real x) (real y) (real vx) (real vy)

          L 8.44818 0.251553  1477010443449633  8.45  0.25  -3.00027  0
          (R) (x) (y) (timestamp) (real x) (real y) (real vx) (real vy)

    Returns:
      all_sensor_data, all_ground_truths
      - two lists of DataPoint() instances 

  """

  all_sensor_data = []
  all_ground_truths = []  

  with open(file_path) as f:
      
    for line in f:
      data = line.split() 
      
      if data[0]  == 'L':
        
        sensor_data = DataPoint({ 
          'timestamp': int(data[3]),
          'name': 'lidar',
          'x': float(data[1]), 
          'y': float(data[2])
        })
        
        g = {'timestamp': int(data[3]),
             'name': 'state',
             'x': float(data[4]),
             'y': float(data[5]),
             'vx': float(data[6]),
             'vy': float(data[7])
        }
          
        ground_truth = DataPoint(g)
                
      elif data[0] == 'R':
          
        sensor_data = DataPoint({ 
          'timestamp': int(data[4]),
          'name': 'radar',
          'rho': float(data[1]), 
          'phi': float(data[2]),
          'drho': float(data[3])
        })
       
        g = {'timestamp': int(data[4]),
             'name': 'state',
             'x': float(data[5]),
             'y': float(data[6]),
             'vx': float(data[7]),
             'vy': float(data[8])
        }
        ground_truth = DataPoint(g)  

      all_sensor_data.append(sensor_data)
      all_ground_truths.append(ground_truth)

  return all_sensor_data, all_ground_truths

# %%
def parse_prediction_data(file_path):
  
  all_predictions = []
    
  with open(file_path) as f:
    
    for line in f:
      data = line.split()
      
      p = {'timestamp': None,
           'name': 'state',
           'x': float(data[0]),
           'y': float(data[1]),
           'vx': float(data[2]),
           'vy': float(data[3])
        }
    
      all_predictions.append(DataPoint(p))
        
  return all_predictions

# %%
all_sensor_data, all_ground_truths = parse_in_data("data/data-1.txt")
all_state_estimations = parse_prediction_data("data/out-1.txt")

# %%
lidar_xs, lidar_ys = [], []
radar_xs, radar_ys, radar_angles = [], [], []
truth_xs, truth_ys, truth_angles = [], [], []
state_xs, state_ys, state_angles = [], [], []
    
for s, t, p in zip(all_sensor_data, all_ground_truths, all_state_estimations):
    
  if s.get_name() == "lidar":
    x, y = s.get_raw()
    lidar_xs.append(x)
    lidar_ys.append(y)
  else:
    x, y, vx, vy = s.get()
    angle = np.arctan2(vy, vx)
    radar_xs.append(x)
    radar_ys.append(y)
    radar_angles.append(angle)

  x, y, vx, vy = t.get()
  t_angle =  np.arctan2(vy, vy)
  truth_xs.append(x)
  truth_ys.append(y)
  truth_angles.append(t_angle)

  x, y, vx, vy = p.get()
  p_angle =  np.arctan2(vy, vx)
  state_xs.append(x)
  state_ys.append(y)
  state_angles.append(p_angle)

# %%
radar_source = ColumnDataSource(data = {
    'x' : radar_xs,
    'y' : radar_ys,
    'angle': radar_angles, 
})

truth_source = ColumnDataSource(data = {
    'x' : truth_xs,
    'y' : truth_ys,
    'angle': truth_angles, 
})

state_source = ColumnDataSource(data = {
    'x' : state_xs,
    'y' : state_ys,
    'angle': truth_angles, 
})

lidar_source = ColumnDataSource(data = {
    'x' : lidar_xs,
    'y' : lidar_ys,
})

# %%
hover1 = HoverTool( tooltips = [
            ("index", "$index"),
            ("x , y", "$x, $y"),
            ("angle radians", "@angle")])

p = figure(plot_width = 1000, plot_height = 700, tools = [hover1])

p.square(
  'x', 'y', size = 5, 
  fill_color = "orange",
  line_color = "orange",
  fill_alpha = 1,
  angle = 'angle', 
  line_width = 1, 
  legend = "radar measurements", 
  source = radar_source)

p.circle(
  'x', 'y', size = 15, 
  fill_color = "green",
  line_color = "white",
  fill_alpha = 0.2,
  line_width = 1, 
  legend = "lidar measurements", 
  source = lidar_source)

p.triangle(
  'x', 'y', size = 7, 
  fill_color = "violet",
  line_color = "violet",
  fill_alpha = 1,
  angle = 'angle', 
  line_width = 0.5, 
  legend = "ground truth",
  source = truth_source)


p.triangle(
  'x', 'y', size = 2, 
  fill_color = "black",
  line_color = "black",
  fill_alpha = 1,
  angle = 'angle', 
  line_width = 1, 
  legend = "state predictions", 
  source = state_source)

p.legend.location = "bottom_right"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b37a161c-22c3-47c3-a648-e148bfd67a82"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b37a161c-22c3-47c3-a648-e148bfd67a82").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b37a161c-22c3-47c3-a648-e148bfd67a82");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b37a161c-22c3-47c3-a648-e148bfd67a82' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ca51e7e0-9ad9-4f22-b17d-84b703be5ea6":{"roots":{"references":[{"attributes":{"label":{"value":"ground truth"},"renderers":[{"id":"3a61fa32-9c83-4e0b-91dc-506305ffea78","type":"GlyphRenderer"}]},"id":"a203acdb-711b-42f0-8b9a-120d6bd6866e","type":"LegendItem"},{"attributes":{"angle":{"field":"angle","units":"rad"},"fill_color":{"value":"black"},"size":{"units":"screen","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"360b90b0-4c02-4867-9fc6-e226805d9970","type":"Triangle"},{"attributes":{"data_source":{"id":"40615c3b-f3de-42ca-987a-9db97e049487","type":"ColumnDataSource"},"glyph":{"id":"8dce9e9e-e90d-427f-bff3-f4c8147d8b65","type":"Triangle"},"hover_glyph":null,"nonselection_glyph":{"id":"eaf700e9-d7ae-4e7a-bba9-f96301ec8dc9","type":"Triangle"},"selection_glyph":null},"id":"3a61fa32-9c83-4e0b-91dc-506305ffea78","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"cd283832-6b97-45bc-be65-182db474b8f0","type":"BasicTickFormatter"},"plot":{"id":"0e69dd7a-429a-4e06-8f14-4598904f3070","subtype":"Figure","type":"Plot"},"ticker":{"id":"6b54cc46-f263-4aeb-8e5f-31305ec12f23","type":"BasicTicker"}},"id":"a69d1228-7485-4d06-a786-7316967f2c2f","type":"LinearAxis"},{"attributes":{"angle":{"field":"angle","units":"rad"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"size":{"units":"screen","value":7},"x":{"field":"x"},"y":{"field":"y"}},"id":"eaf700e9-d7ae-4e7a-bba9-f96301ec8dc9","type":"Triangle"},{"attributes":{"angle":{"field":"angle","units":"rad"},"fill_color":{"value":"orange"},"line_color":{"value":"orange"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"29581f42-f161-4e26-bcb8-f5248861d510","type":"Square"},{"attributes":{"callback":null,"column_names":["y","angle","x"],"data":{"angle":[-3.1128324535897933,-3.113360853589793,-3.1114499535897933,-3.1178489535897933,-3.1211273535897934,-3.1288894535897933,-3.140908881589793,3.120370253589793,3.0896624535897934,3.057502253589793,3.0107806535897934,2.9623736535897933,-0.226407,2.862153653589793,-0.322252,-0.36264,-0.399959,-0.43502,-0.470836,-0.4961400000000001,-0.5214370000000002,-0.547179,-0.567708,-0.582556,-0.6044940000000001,-0.622421,-0.6346800000000001,-0.647271,-0.659824,-0.66785,-0.678464,-0.6876069999999999,-0.696337,-0.707378,-0.716035,-0.726017,-0.735521,-0.745345,-0.755304,-0.765199,-0.7723620000000001,-0.782802,-0.794831,-0.803954,-0.812263,-0.8244549999999999,-0.8359559999999999,-0.848604,-0.8637739999999999,-0.8772439999999999,-0.88995,-0.905673,-0.922266,-0.9368469999999999,2.1841526535897935,2.1628196535897932,2.1463466535897933,2.1292926535897934,2.111082653589793,2.0931626535897934,2.0740426535897933,2.059152653589793,2.043912653589793,2.025932653589793,2.009392653589793,1.994752653589793,1.9835526535897934,1.970752653589793,1.9577026535897932,1.9483126535897932,1.9460626535897934,1.9475326535897934,1.9457926535897931,1.9534526535897934,1.9618926535897934,1.970152653589793,1.9865126535897932,2.0057126535897933,2.025142653589793,2.0508626535897934,2.075572653589793,2.1007626535897934,2.1313826535897933,2.1532346535897933,2.1841616535897934,2.2186926535897933,2.2480456535897932,2.278964653589793,-0.830934,2.3381236535897933,-0.773882,2.3998966535897934,-0.7145819999999999,-0.690878,-0.663884,-0.632288,-0.6060640000000002,-0.579689,-0.5556,-0.529976,-0.506831,-0.4856690000000001,-0.456323,-0.4267040000000001,-0.396158,-0.37096000000000007,-0.345253,-0.322404,-0.292989,-0.262561,-0.236058,2.932269653589793,-0.185161,2.984068653589793,3.0118436535897932,3.031280653589793,3.056199253589793,3.0806118535897933,3.1012752535897934,3.118271553589793,3.133849733589793,-3.1411938955897933,-3.135516683589793,-3.129537053589793,-3.1194396535897932,-3.113837153589793,-3.111022953589793,-3.1115619535897934,-3.115173053589793,-3.1291233535897933,-3.1356487635897934,3.135049343589793,3.104979953589793,3.07386475358979 ...

# %%
hover2 = HoverTool( tooltips = [
            ("index", "$index"),
            ("x , y", "$x, $y"),
            ("angle radians", "@angle")])

p = figure(plot_width = 1000, plot_height = 700, tools = [hover2])

p.square(
  'x', 'y', size = 5, 
  fill_color = "violet",
  line_color = "violet",
  fill_alpha = 1,
  angle = 'angle', 
  line_width = 1, 
  legend = "radar measurements", 
  source = radar_source)

p.circle(
  'x', 'y', size = 10, 
  fill_color = "green",
  line_color = "white",
  fill_alpha = 0.4,
  line_width = 1, 
  legend = "lidar measurements", 
  source = lidar_source)

p.line(state_xs, state_ys, line_width = 2, color='orange', legend = "state predictions")
p.line(truth_xs, truth_ys, line_dash = "4 4", line_width = 1, color='navy', legend = "ground truth")

p.legend.location = "bottom_right"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d7b7e059-5122-4384-add5-547497675f51"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d7b7e059-5122-4384-add5-547497675f51").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d7b7e059-5122-4384-add5-547497675f51");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd7b7e059-5122-4384-add5-547497675f51' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"744e87bb-3cbb-4a93-b8aa-d17f00f9dc25":{"roots":{"references":[{"attributes":{"label":{"value":"ground truth"},"renderers":[{"id":"5776bab0-16c1-4512-878c-dade777fabe4","type":"GlyphRenderer"}]},"id":"1e4a7d73-e613-461b-bb14-9a8bf073ee52","type":"LegendItem"},{"attributes":{},"id":"97afa002-a85e-4511-83db-80f16859ca79","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"05de3f0d-4699-4e13-8748-1c231cda772c","type":"Circle"},{"attributes":{"data_source":{"id":"a7373a6f-edf7-41c4-b789-b923ec96379b","type":"ColumnDataSource"},"glyph":{"id":"777f3768-b0e2-4a03-86b8-6522cdcecbdb","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"05de3f0d-4699-4e13-8748-1c231cda772c","type":"Circle"},"selection_glyph":null},"id":"298ff80f-d9ed-4cb7-83fc-966ddf1d81c2","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"bc515cf8-29b0-49de-b643-e798919d2d64","type":"LinearAxis"}],"left":[{"id":"a34ae40f-3f0f-45a9-901a-d071f2e05b4d","type":"LinearAxis"}],"plot_height":700,"plot_width":1000,"renderers":[{"id":"bc515cf8-29b0-49de-b643-e798919d2d64","type":"LinearAxis"},{"id":"accff06a-5c33-42f6-9386-988292ed28b8","type":"Grid"},{"id":"a34ae40f-3f0f-45a9-901a-d071f2e05b4d","type":"LinearAxis"},{"id":"fe69f06c-09f0-4d94-b25f-7dd3da8a2b83","type":"Grid"},{"id":"63480ce5-0b78-4a80-921e-b7b4d49c5630","type":"Legend"},{"id":"b35da26f-ab9f-4dd1-9f04-ba201dda5ea5","type":"GlyphRenderer"},{"id":"298ff80f-d9ed-4cb7-83fc-966ddf1d81c2","type":"GlyphRenderer"},{"id":"d2859b13-eef6-4434-a823-b26a2bf46e65","type":"GlyphRenderer"},{"id":"5776bab0-16c1-4512-878c-dade777fabe4","type":"GlyphRenderer"}],"title":{"id":"a60152b3-f423-4be6-845b-aff3aad247c3","type":"Title"},"tool_events":{"id":"afe147bb-897d-4a91-a66f-a803522b3c27","type":"ToolEvents"},"toolbar":{"id":"9054ae8b-51bf-4038-a4b0-d869252b974c","type":"Toolbar"},"x_range":{"id":"164b121f-aa2a-4670-9194-e9eb18bb6c5e","type":"DataRange1d"},"y_range":{"id":"add29181-c2b3-4624-a8fa-ce8a66ffed28","type":"DataRange1d"}},"id":"b2aaab44-234f-4701-809f-f7db92083166","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"add29181-c2b3-4624-a8fa-ce8a66ffed28","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[8.6,8.45,8.45,8.45,8.35,8.25,8.05,7.85,7.7,7.55,7.45,7.35,7.2,7.05,6.95,6.85,6.75,6.65,6.6,6.55,6.5,6.45,6.35,6.25,6.3,6.35,6.3,6.25,6.3,6.35,6.35,6.35,6.4,6.45,6.45,6.45,6.5,6.55,6.65,6.75,6.8,6.85,6.9,6.95,7.0,7.05,7.1,7.15,7.25,7.35,7.4,7.45,7.55,7.65,7.7,7.75,7.85,7.95,8.05,8.15,8.2,8.25,8.35,8.45,8.5,8.55,8.65,8.75,8.8,8.85,8.9,8.95,9.0,9.05,9.1,9.15,9.2,9.25,9.35,9.45,9.5,9.55,9.55,9.55,9.6,9.65,9.7,9.75,9.75,9.75,9.8,9.85,9.85,9.85,9.85,9.85,9.85,9.85,9.8,9.75,9.7,9.65,9.6,9.55,9.45,9.35,9.3,9.25,9.05,8.85,8.75,8.65,8.5,8.35,8.2,8.05,7.9,7.75,7.6,7.45,7.3,7.15,7.0,6.85,6.7,6.55,6.4,6.25,6.1,5.95,5.8,5.65,5.55,5.45,5.3,5.15,5.05,4.95,4.85,4.75,4.7,4.65,4.6,4.55,4.5,4.45,4.45,4.45,4.45,4.45,4.45,4.45,4.5,4.55,4.6,4.65,4.7,4.75,4.85,4.95,5.0,5.05,5.15,5.25,5.35,5.45,5.5,5.55,5.7,5.85,5.95,6.05,6.15,6.25,6.35,6.45,6.6,6.75,6.8,6.85,7.0,7.15,7.25,7.35,7.5,7.65,7.75,7.85,8.0,8.15,8.25,8.35,8.5,8.65,8.75,8.85,8.95,9.05,9.2,9.35,9.45,9.55,9.65,9.75,9.85,9.95,10.05,10.15,10.25,10.35,10.45,10.55,10.65,10.75,10.8,10.85,10.95,11.05,11.1,11.15,11.2,11.25,11.2,11.15,11.25,11.35,11.35,11.35,11.3,11.25,11.2,11.15,11.05,10.95,10.9,10.85,10.75,10.65,10.5,10.35,10.25,10.15,10.0,9.85,9.7,9.55,9.4,9.25,9.1,8.95,8.85,8.75,8.55,8.35,8.2,8.05,7.9,7.75,7.6,7.45,7.3,7.15,7.05,6.95,6.85,6.75,6.65,6.55,6.5,6.45,6.4,6.35,6.3,6.25,6.25,6.25,6.3,6.35,6.35,6.35,6.35,6.35,6.4,6.45,6.5,6.55,6.6,6.65,6.7,6.75,6.8,6.85,6.95,7.05,7.1,7.15,7.2,7.25,7.35,7.45,7.5,7.55,7.65,7.75,7.8,7.85,7.95,8.05,8.15,8.25,8.3,8.35,8.4,8.45,8.55,8.65,8.7,8.75,8.85,8.95,9.0,9.05,9. ...

# %%
all_sensor_data, all_ground_truths = parse_in_data("data/data-2.txt")
all_state_estimations = parse_prediction_data("data/out-2.txt")

# %%
lidar_xs, lidar_ys = [], []
radar_xs, radar_ys, radar_angles = [], [], []
truth_xs, truth_ys, truth_angles = [], [], []
state_xs, state_ys, state_angles = [], [], []
    
for s, t, p in zip(all_sensor_data, all_ground_truths, all_state_estimations):
    
  if s.get_name() == "lidar":
    x, y = s.get_raw()
    lidar_xs.append(x)
    lidar_ys.append(y)
  else:
    x, y, vx, vy = s.get()
    angle = np.arctan2(vy, vx)
    radar_xs.append(x)
    radar_ys.append(y)
    radar_angles.append(angle)

  x, y, vx, vy = t.get()
  t_angle =  np.arctan2(vy, vy)
  truth_xs.append(x)
  truth_ys.append(y)
  truth_angles.append(t_angle)

  x, y, vx, vy = p.get()
  p_angle =  np.arctan2(vy, vx)
  state_xs.append(x)
  state_ys.append(y)
  state_angles.append(p_angle)

radar_source = ColumnDataSource(data = {
    'x' : radar_xs,
    'y' : radar_ys,
    'angle': radar_angles, 
})

truth_source = ColumnDataSource(data = {
    'x' : truth_xs,
    'y' : truth_ys,
    'angle': truth_angles, 
})

state_source = ColumnDataSource(data = {
    'x' : state_xs,
    'y' : state_ys,
    'angle': truth_angles, 
})

lidar_source = ColumnDataSource(data = {
    'x' : lidar_xs,
    'y' : lidar_ys,
})

# %%
hover3 = HoverTool( tooltips = [
            ("index", "$index"),
            ("x , y", "$x, $y"),
            ("angle radians", "@angle")])

p = figure(plot_width = 1000, plot_height = 700, tools = [hover3])

p.square(
  'x', 'y', size = 5, 
  fill_color = "orange",
  line_color = "orange",
  fill_alpha = 1,
  angle = 'angle', 
  line_width = 1, 
  legend = "radar measurements", 
  source = radar_source)

p.circle(
  'x', 'y', size = 15, 
  fill_color = "green",
  line_color = "white",
  fill_alpha = 0.2,
  line_width = 1, 
  legend = "lidar measurements", 
  source = lidar_source)

p.triangle(
  'x', 'y', size = 7, 
  fill_color = "violet",
  line_color = "violet",
  fill_alpha = 1,
  angle = 'angle', 
  line_width = 0.5, 
  legend = "ground truth",
  source = truth_source)


p.triangle(
  'x', 'y', size = 2, 
  fill_color = "black",
  line_color = "black",
  fill_alpha = 1,
  angle = 'angle', 
  line_width = 1, 
  legend = "state predictions", 
  source = state_source)

p.legend.location = "bottom_right"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="de565068-1b86-4b98-b0f4-9dc1cf557186"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("de565068-1b86-4b98-b0f4-9dc1cf557186").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("de565068-1b86-4b98-b0f4-9dc1cf557186");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'de565068-1b86-4b98-b0f4-9dc1cf557186' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aab0119c-99db-4ba5-a17d-44a46d90c8aa":{"roots":{"references":[{"attributes":{"angle":{"field":"angle","units":"rad"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3e29191a-f29b-4f00-9420-12290f7de62c","type":"Triangle"},{"attributes":{"callback":null},"id":"2fdf669f-f961-452e-b937-1771bdaffa64","type":"DataRange1d"},{"attributes":{"plot":{"id":"68ebc8e0-5dc5-4959-a604-21f90357a552","subtype":"Figure","type":"Plot"},"ticker":{"id":"99df1689-37f7-4e42-b25c-033e4b5c5172","type":"BasicTicker"}},"id":"ca6090e9-52c2-4afe-9acf-bd66093d5023","type":"Grid"},{"attributes":{},"id":"04231f1b-2de7-4b24-858b-dea2a141959f","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,1.559445,3.890927,6.863517,9.077331,11.57555,13.59209,16.64559,19.01058,21.33124,24.07871,26.60525,29.58639,31.9416,34.61568,37.14036,40.32853,42.76639,45.35721,48.15409,50.62278,53.72678,56.03223,58.6632,60.87224,63.38208,66.34029,68.26205,70.82748,72.89226,75.00209,77.12245,79.1089,80.80743,82.62158,84.17335,85.63776,86.94492,88.82267,89.49667,90.51327,91.71782,92.85989,93.46683,95.32289,95.50389,96.26405,97.52863,98.21047,99.03627,99.99686,101.2038,102.3868,103.0034,104.1144,105.5409,106.8312,108.0836,109.5344,111.063,112.9126,114.801,116.6871,118.9528,120.6951,123.5682,124.8938,127.8531,129.9473,132.0919,135.0735,137.5606,140.3314,142.8884,145.392,148.2509,150.6859,153.422,156.0466,158.9049,161.4116,163.6251,166.8278,169.0972,172.1752,174.643,177.0301,180.1454,182.5994,184.7319,186.9463,189.4652,191.7353,193.4712,195.9914,197.7246,199.2941,201.5491,202.9624,203.9906],"y":[0.0,-0.1385015,-0.1341657,0.4168175,0.5932112,1.6669,2.311915,2.902999,3.705553,4.732053,5.569675,6.96102,8.08789,9.880168,10.6988,12.08833,13.46661,14.82937,16.55239,17.28347,19.07211,19.89821,21.0923,21.78207,22.78765,23.4069,23.99586,24.35817,24.88439,24.71354,25.25945,24.92967,25.03687,24.86882,24.63932,24.55042,23.80798,23.52704,22.78691,22.30817,21.66767,21.11524,20.95372,20.21548,19.65849,19.6984,19.15973,18.72696,18.3739,17.35698,16.98822,16.53684,16.39923,15.35302,15.27083,14.44125,14.04819,13.6604,13.57136,12.58139,12.48773,12.55057,12.10355,12.00094,12.2918,12.8297,12.77429,13.32727,13.6963,14.50702,15.04748,16.2147,17.00802,17.99183,19.16167,20.47536,22.11423,23.49086,24.80844,26.03078,27.42561,28.76827,30.20623,31.37172,32.34041,33.46252,34.20094,35.14229,35.75303,36.51547,36.94045,37.40516,37.56307,37.27891,37.39908,37.72855,37.28617,36.99733,36.45683,36.1967]}},"id":"8f840ff4-edb4-4ac0-a485-636fe7c3f7fc","type":"ColumnDataSource"},{"attributes":{},"id":"99df1689-37f7-4e42-b25c-033e4b5c5172","type":"BasicTicker"},{"attributes":{"angle":{"field":"angle","units":"rad"},"fill_color":{"value":"orange"},"line_color":{"value":"orange"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"77cae204-b51a-491b-9f63-8c7f0f7f44ba","type":"Square"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"green"},"line_color":{"value":"white"},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"c843015a-14b5-4dd3-ae9c-bdd3e38a205f","type":"Circle"},{"attributes":{"callback":null,"column_names":["y","angle","x"],"data":{"angle":[0.0,0.0,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.7853981633974483,0.78 ...

# %%
hover4 = HoverTool( tooltips = [
            ("index", "$index"),
            ("x , y", "$x, $y"),
            ("angle radians", "@angle")])

p = figure(plot_width = 1000, plot_height = 700, tools = [hover4])

p.square(
  'x', 'y', size = 5, 
  fill_color = "violet",
  line_color = "violet",
  fill_alpha = 1,
  angle = 'angle', 
  line_width = 1, 
  legend = "radar measurements", 
  source = radar_source)

p.circle(
  'x', 'y', size = 10, 
  fill_color = "green",
  line_color = "white",
  fill_alpha = 0.4,
  line_width = 1, 
  legend = "lidar measurements", 
  source = lidar_source)

p.line(state_xs, state_ys, line_width = 2, color='orange', legend = "state predictions")
p.line(truth_xs, truth_ys, line_dash = "4 4", line_width = 1, color='navy', legend = "ground truth")

p.legend.location = "bottom_right"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="efb3d7ec-a7f5-4b4e-93af-eec82d406ab9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("efb3d7ec-a7f5-4b4e-93af-eec82d406ab9").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("efb3d7ec-a7f5-4b4e-93af-eec82d406ab9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'efb3d7ec-a7f5-4b4e-93af-eec82d406ab9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cdd530af-5937-4eaa-9c0d-887a7cdb3f7e":{"roots":{"references":[{"attributes":{"label":{"value":"lidar measurements"},"renderers":[{"id":"eceb7fc7-1503-4c58-a1f7-75c861d7cf45","type":"GlyphRenderer"}]},"id":"31c1d355-66e2-4944-8f55-5359bbb0b20a","type":"LegendItem"},{"attributes":{"data_source":{"id":"37a406dd-a276-4ca6-a033-a4dd6d144c55","type":"ColumnDataSource"},"glyph":{"id":"19f3161f-4ad0-42a1-838e-406cc71ea471","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"fd58de00-5ab6-47a6-b10e-a452494f177b","type":"Line"},"selection_glyph":null},"id":"941cac08-7da8-4620-a071-e18857293639","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"08d60f4b-07bb-4125-ab4d-25771b96a604","type":"ColumnDataSource"},"glyph":{"id":"1f1a7743-70ea-452f-97ef-ff030dc13856","type":"Square"},"hover_glyph":null,"nonselection_glyph":{"id":"7f8feda6-2b49-47b8-9520-f3e8d38748c7","type":"Square"},"selection_glyph":null},"id":"c1b66a2e-a9fd-4521-8985-ea0914709451","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","angle","x"],"data":{"angle":[0.0,0.02619727,0.05202598,0.07330529,0.09936074,0.1242681,0.14534909999999998,0.1730753,0.19732670000000002,0.2161499,0.2366585,0.2543628,0.2727931,0.290333,0.3039004,0.3168263,0.32904120000000003,0.33838380000000007,0.3472554,0.350698,0.355617,0.3553123,0.3593175,0.3589798,0.35664870000000004,0.3565512,0.3487223,0.3440404,0.3355868,0.33006009999999997,0.323504,0.3168645,0.3055133,0.2974122,0.29211100000000007,0.2810227,0.26957490000000006,0.2621807,0.25395300000000004,0.24536720000000004,0.2386165,0.2297548,0.2220744,0.21536759999999996,0.207415,0.20200169999999995,0.1929804,0.1842182,0.18242699999999998,0.1729878,0.1672018,0.1610466,0.153904,0.14606379999999997,0.1411149,0.13218269999999996,0.1329968,0.125884,0.11969140000000002,0.115752,0.113206,0.10678909999999998,0.10287660000000001,0.10400970000000002,0.1004631,0.10332689999999999,0.1032906,0.1027923,0.10534460000000001,0.1078673,0.1080497,0.1194011,0.12435340000000002,0.126547,0.1321468,0.1404008,0.1438054,0.14819950000000004,0.1593196,0.16323860000000004,0.17070920000000003,0.1767602,0.1763346,0.17937480000000003,0.1875434,0.1919932,0.1887235,0.19508160000000002,0.1966203,0.1931176,0.19471610000000003,0.19234,0.1912593,0.1909903,0.1894537,0.186601,0.18521909999999997,0.18436010000000003,0.1817587,0.17623209999999997],"x":[0.0,1.8120890065536968,4.195282898131183,6.439263951838519,8.897494094590057,11.444709998562601,13.657165989272517,16.28195527013715,19.363047979292386,21.621344108905937,24.560055363578353,26.541910417680082,29.47157812077767,31.792798199174168,35.05993022827336,37.49732769560551,39.900941693889585,42.571418733066885,45.64898040657271,47.93305501262085,50.5736513340699,53.52770394894018,55.8669730738404,58.579938550190896,60.764808537463345,63.74778170921791,65.88384342247551,68.67592580850912,70.7403296216073,73.0731712914125,74.9747821562663,77.13859354321183,79.17177113047259,81.1423002728638,82.50846076380661,84.28976505279456,85.97430637614002,87.61705943212222,88.41905450805521,89.78205385511532,90.84185210246,92.04917907179099,93.31857958173161,93.74234112734182,94.49395448086288,95.60968374739882,96.55895399200789,97.53327961948968,98.41615468912647,98.97815733129316,100.44057706513598,101.16930696477358,102.08068815353765,102.77582654264684,103.90499434379076,105.31590025369279,106.43875960011057,108.13143858278916,109.3876500232867,111.42573952890967,112.79694011066982,114.91642361180433,116.87120218708426,118.84992917989058,120.93423833970587,123.14220229018764,125.37589942108642,127.5063888288843,130.3344485564308,132.446615000554,135.1266605192927,137.65320233691628,140.30474598765764,142.6256163737405,145.78932837378665,148.14635115055142,150.64925114427615,153.46554947246355,156.009171438787,159.01391055766305,161.52867447954372,164.11556634790054,166.74825687834473,169.34502678163898,172.13478419876878,174.4744732696961,177.21134920572447,179.54285820847 ...
